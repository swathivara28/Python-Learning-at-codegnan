# %%
t = (1,2,3,4,"HI",[10,20,30],50)
print(t)
print(t[5])
print(t[5][1])
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30], 50)
# [10, 20, 30]
# 20

# %%
t = (1,2,3,4, "HI", [10,20,30],50)
t[5].append(100)
print(t)
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30, 100], 50)

# %%
# define empty tuple
t1 = ()
t2 =tuple()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
l1 = [10]
t1 = (10)
t2 = (10,)
print(type(l1),type(t1),type(t2))
# Out:
# <class 'list'> <class 'int'> <class 'tuple'>

# %%
# Dictionary ordered collection
details = {'name':'Ravi','age':20,'course':'python'}
print(details)
# Out:
# {'name': 'Ravi', 'age': 20, 'course': 'python'}

# %%
# Dictionary ordered collection
details = {'name':'Ravi','age':20,'course':'python',[1,2,3]:10}
print(details)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Dictionary ordered collection
# ----> 2 details = {'name':'Ravi','age':20,'course':'python',[1,2,3]:10}
#       3 print(details)
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
# Dictionary can't allow list as key
# If dictionary contain multiple items with  same key,In that case it updates first item  key value with last defined item value
details = {'name':'Ravi','age':20,'course':'python','marks':[85,90,86],'age':50}
print(details)
# Out:
# {'name': 'Ravi', 'age': 50, 'course': 'python', 'marks': [85, 90, 86]}

# %%
# access values by using keys
details = {'name':'Ravi','age':20,'course':'python','marks':[85,90,86],'age':50}
print(details['course'])
print(details['age'])
# updating the dictionary values
details['age'] += 1
details['course'] = 'java' # It updates the value for 'course' key
print(details)
# items assignment
details['location'] = "India" # It adds new item to dictionary
print(details)
# Out:
# python
# 50
# {'name': 'Ravi', 'age': 51, 'course': 'java', 'marks': [85, 90, 86]}
# {'name': 'Ravi', 'age': 51, 'course': 'java', 'marks': [85, 90, 86], 'location': 'India'}

# %%
# define empty dictionary
d1 = {}
d2 = dict()
print(type(d1),type(d2))
# Out:
# <class 'dict'> <class 'dict'>

# %%
#### Dictionary Methods
-Get value
   -get(key,default_val): It returns the value if key exists in dictionary otherwise 'default_val'
-update values Add items to dictionary
 -update(new_dictionary): Dictionary updates with New_dictionary Items
-Removes items from dictionary
  -pop(key): It returns value and remove item if key is exists in dictionary otherwise 'KeyError'
  -popitem(): It returns tuple of key value pair and removes the last item from dictionary
-Get Keys,value and items from dictionary
 -keys(): It returns list od dictionary keys
 -values(): It returns list of dictionary values
 -items(): It returns list of tuple key-value pairs

# %%
details = {'name':'Ravi','age':20,'course':'python','marks':[85,90,86],'age':50}
#print(details['location'])
print(details.get('name'))
print(details.get('location'))
print(details.get('age',18))
print(details.get('location',"Location key not exists"))
# Out:
# Ravi
# None
# 50
# Location key not exists

# %%
details = {'name':'Ravi','age':20,'course':'python'}
d = {'marks':[85,90,86],'age':50}
details.update(d)
print(details)
# Out:
# {'name': 'Ravi', 'age': 50, 'course': 'python', 'marks': [85, 90, 86]}

# %%
details = {'name':'Ravi','age':20,'course':'python','marks':[85,90,86],'age':50}
print(details)
print(details.pop('age'))
print(details)
print(details.popitem())# return type is tuple for this popitem
print(details)
print(details.pop('percentage'))
# Out:
# {'name': 'Ravi', 'age': 50, 'course': 'python', 'marks': [85, 90, 86]}
# 50
# {'name': 'Ravi', 'course': 'python', 'marks': [85, 90, 86]}
# ('marks', [85, 90, 86])
# {'name': 'Ravi', 'course': 'python'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 7
#       3 print(details.pop('age'))
#       4 print(details)
#       5 print(details.popitem())# return type is tuple for this popitem
#       6 print(details)
# ----> 7 print(details.pop('percentage'))
#       8 print(details.key())
#       9 print(details)
#
# KeyError: 'percentage'

# %%
details = {'name':'Swathi','age':20,'course':'Java','marks':[85,90,86],'age':40}
keys = details.keys()
print(type(keys))
print(keys)
print(details.values())
print(details.items())
print(list(keys))
# Out:
# <class 'dict_keys'>
# dict_keys(['name', 'age', 'course', 'marks'])
# dict_values(['Swathi', 40, 'Java', [85, 90, 86]])
# dict_items([('name', 'Swathi'), ('age', 40), ('course', 'Java'), ('marks', [85, 90, 86])])
# ['name', 'age', 'course', 'marks']

# %%
# check memory size of object
import sys
print(sys.getsizeof([1,2,3]))
print(sys.getsizeof((1,2,3)))
# Out:
# 88
# 72

# %%
s = "Bhulakshmi"
f = {}
for ch in s:
    if ch in f:
        f[ch] = f[ch]+1
    else:
        f[ch]=1
print(f)
# Out:
# {'B': 1, 'h': 2, 'u': 1, 'l': 1, 'a': 1, 'k': 1, 's': 1, 'm': 1, 'i': 1}
