# %%
n= int(input())
if n % 2==0:
    print("even")
if n % 2==1:
    print("odd")
# Out:
#  8
# even

# %%
num = int(input())
if n % 3 ==0:
    print("FIZZ")
if n % 5 ==0:
    print("BUZZ")
else:
    print(num)
# Out:
#  6
# FIZZ
# 6

# %%
num = int(input())
if n % 3 ==0:
    print("FIZZ")
elif n % 5 ==0:
    print("BUZZ")
elif n % 3==0 and n % 5==0:
    print("FIZZBUZZ")
else: 
    print(num)
# Out:
#  15
# FIZZ

# %%
num = int(input())
if num > 0:
    print("positive")
elif n < 0:
    print("negitive")
else:
    print("zero")
# Out:
#  4
# positive

# %%
num = int(input())
if num >=0 and num % 2 == 0:
    print("positive even")
elif num  >=0 and num % 2 ==1:
    print("negitive odd")
elif num < 0 and num % 2 == 0:
    print("negitive even")
else:
    print("negitive odd")
# Out:
#  -8
# negitive even

# %%
## Another way of writing code
num = int(input())
if num > 0 and num % 2 == 0:
    print("positive even")
elif num  >0:
    print("positive odd")
elif num < 0 and num % 2 == 0:
    print("negitive even")
elif num < 0:
    print("negitive odd")
else:
    print("Zero")
# Out:
#  35
# positive odd

# %%
# Find the smallest number among the three numbers
a = int(input())
b = int(input())
c = int(input())
if a <= b and a <= c:
    print("smallest number is a")
elif b <= a and b <= c:
    print(" smallest number is b")
elif c <= b and c <= a: 
    print("print smallest number is c")
else:
    print("among the smallest number")
# Out:
#  234
#  59
#  545
#  smallest number is b

# %%
num = int(input())
if num > 0:  
    if num % 2 == 0:
    print("positive even")
    else:
        print("positive odd")
else:
   if num % 2 == 0:
    print("negitive even")
   else:
    print("negitive odd")
else:
    print("Zero")
# Out:
#  -3
# negitive odd

# %%
a = int(input())
b = int(input())
c = int(input())
if a >=b and a>=c:
print(
