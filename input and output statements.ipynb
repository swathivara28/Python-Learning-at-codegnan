# %%
# 
name = "Ravi"
age = 20
marks = [85,98,65,85,78,98]
#my name is Ravi and i am a 20 years old
print("My name " + name + " and i am " +  str(age)  + "years old")
# Out:
# My name Ravi and i am 20years old

# %%
## Output Formating
# 1. Old style Formating (using camma)
name = "Swathi"
age = 20
marks = [85,98,65,85,78,98]
#my name is Ravi and i am a 20 years old
print("My name " , name , " and i am " ,age ,"years old")
# Out:
# My name  Swathi  and i am  20 years old

# %%
# 1.Access specifiers
# integer -%d
# float - %f
# string -%s
name = "Swathi"
age = 20
marks = [85,98,65,85,78,98]
#my name is Ravi and i am a 20 years old
print("My name %s and i am a %d years old" %(name,age))
# Out:
# My name Swathi and i am a 20 years old

# %%
## Output Formating
# 3. Dot Format
name = "Swathi"
age = 20
marks = [85,98,65,85,78,98]
#my name is Ravi and i am a 20 years old
print("My name {} and i am a {} years old".format(name,age))
print("My name {} and i am a {} years old".format(age,name))
# Out:
# My name Swathi and i am a 20 years old
# My name 20 and i am a Swathi years old

# %%
# f-format
name = "Ravi"
age = 20
marks = [85,98,65,85,78,98]
#my name is Ravi and i am a 20 years old
percentage = 98.2568
print(f"My name {name}.i am a {age} years old and my percentage is {percentage}")
print(f"My name {name}.i am a {age} years old and my percentage is {percentage:2f}")
# Out:
# My name Ravi.i am a 20 years old and my percentage is 98.2568
# My name Ravi.i am a 20 years old and my percentage is 98.256800
